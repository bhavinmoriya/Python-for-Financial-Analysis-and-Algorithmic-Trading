# %% [markdown]
# <a href="https://www.kaggle.com/code/bhavinmoriya/stock-market-analysis-project?scriptVersionId=109419073" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# <center>*Copyright Pierian Data 2017*</center>
# <center>*For more information, visit us at www.pieriandata.com*</center>

# %% [markdown]
# # Stock Market Analysis Project
#
# ### Please Note: You are free to treat this as a full exercise, or just view the solutions video as a code along project. This project is meant to be pretty challenging as it will introduce a few new concepts through some hints!
#
# Welcome to your first capstone project! This project is meant to cap off the first half of the course, which mainly dealt with learning the libraries that we use in this course, the second half of the course will deal a lot more with quantitative trading techniques and platforms.
#
# We'll be analyzing stock data related to a few car companies, from Jan 1 2012 to Jan 1 2017. Keep in mind that this project is mainly just to practice your skills with matplotlib, pandas, and numpy. Don't infer financial trading advice from the analysis we do here!
#
# ### Part 0: Import
#
# ** Import the various libraries you will need-you can always just come back up here or import as you go along :) **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly_express as px
import seaborn as sns
import pandas_datareader as web
from datetime import datetime as dt

# %% [markdown]
# ____
# ## Part 1: Getting the Data
#
# ### Tesla Stock (Ticker: TSLA on the NASDAQ)
#
# **  *Note! Not everyone will be working on a computer that will give them open access to download the stock information using pandas_datareader (firewalls, admin permissions, etc...). Because of this, the csv file for the Tesla is provided in a data folder inside this folder. It is called Tesla_Stock.csv. Feel free to just use this with read_csv! **
#
# ** Use pandas_datareader to obtain the historical stock information for Tesla from Jan 1, 2012 to Jan 1, 2017.**

# %%
ticker = 'TSLA'
start = dt(2012,1,1)
end = dt(2017,1,1)
tsla = web.get_data_yahoo(ticker, start, end)

# %%
tsla
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2012-01-03   1.966667   1.843333   1.929333   1.872000  13921500   1.872000
# 2012-01-04   1.911333   1.833333   1.880667   1.847333   9451500   1.847333
# 2012-01-05   1.862000   1.790000   1.850667   1.808000  15082500   1.808000
# 2012-01-06   1.852667   1.760667   1.813333   1.794000  14794500   1.794000
# 2012-01-09   1.832667   1.741333   1.800000   1.816667  13455000   1.816667
# ...               ...        ...        ...        ...       ...        ...
# 2016-12-23  14.230000  13.847333  13.866667  14.222667  70057500  14.222667
# 2016-12-27  14.816667  14.294667  14.325333  14.635333  88735500  14.635333
# 2016-12-28  14.920000  14.480000  14.768667  14.649333  56737500  14.649333
# 2016-12-29  14.613333  14.274667  14.570667  14.312000  60675000  14.312000
# 2016-12-30  14.500000  14.112000  14.420000  14.246000  69639000  14.246000
#
# [1258 rows x 6 columns]

# %% [markdown]
# For some reason, data from csv and from Pandas Datareader do not match. I will be very grateful if you have some insight on it:) To play safe, I would go with csv.

# %%
tsla = pd.read_csv('../input/tesla-stock/Tesla_Stock.csv', index_col=0,parse_dates=True)
tsla
# Out:
#               Open    High     Low   Close   Volume
# Date
# 2012-01-03   28.94   29.50   27.65   28.08   928052
# 2012-01-04   28.21   28.67   27.50   27.71   630036
# 2012-01-05   27.76   27.93   26.85   27.12  1005432
# 2012-01-06   27.20   27.79   26.41   26.89   687081
# 2012-01-09   27.00   27.49   26.12   27.25   896951
# ...            ...     ...     ...     ...      ...
# 2016-12-23  208.00  213.45  207.71  213.34  4670464
# 2016-12-27  214.88  222.25  214.42  219.53  5915732
# 2016-12-28  221.53  223.80  217.20  219.74  3782456
# 2016-12-29  218.56  219.20  214.12  214.68  4044968
# 2016-12-30  216.30  217.50  211.68  213.69  4642620
#
# [1258 rows x 5 columns]

# %% [markdown]
# ### Other Car Companies
#
# ** Repeat the same steps to grab data for Ford and GM (General Motors), **

# %%
ford = pd.read_csv('../input/ford-stock/Ford_Stock.csv', index_col=0, parse_dates=True)
ford
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709811
# 2012-01-04  11.15  11.53  11.07  11.30  79725188
# 2012-01-05  11.33  11.63  11.24  11.59  67877467
# 2012-01-06  11.74  11.80  11.52  11.71  59840605
# 2012-01-09  11.83  11.95  11.70  11.80  53981467
# ...           ...    ...    ...    ...       ...
# 2016-12-23  12.43  12.46  12.36  12.46  15621178
# 2016-12-27  12.43  12.51  12.36  12.39  19467440
# 2016-12-28  12.37  12.45  12.22  12.25  26875381
# 2016-12-29  12.25  12.31  12.22  12.23  19819081
# 2016-12-30  12.24  12.28  12.08  12.13  27405736
#
# [1258 rows x 5 columns]

# %%
gm = pd.read_csv('../input/gm-stock/GM_Stock.csv', index_col=0, parse_dates=True)
gm
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321420
# 2012-01-04  21.05  21.37  20.75  21.15   7856752
# 2012-01-05  21.10  22.29  20.96  22.17  17884040
# 2012-01-06  22.26  23.03  22.24  22.92  18234608
# 2012-01-09  23.20  23.43  22.70  22.84  12091714
# ...           ...    ...    ...    ...       ...
# 2016-12-23  35.83  35.87  35.54  35.69   9351152
# 2016-12-27  35.80  35.93  35.50  35.54   6008707
# 2016-12-28  35.74  35.80  35.13  35.15   8451852
# 2016-12-29  35.25  35.48  35.12  35.14   4416668
# 2016-12-30  35.21  35.31  34.67  34.84   7646079
#
# [1258 rows x 5 columns]

# %% [markdown]
# ## Part 2: Visualizing the Data
#
# ** Time to visualize the data. **
#
# ** Follow along and recreate the plots below according to the instructions and explanations. **

# %% [markdown]
# ____
#
# ** Recreate this linear plot of all the stocks' Open price ! Hint: For the legend, use label parameter and plt.legend()**

# %%
allopen = pd.concat([tsla.Open, gm.Open, ford.Open], axis=1)
allopen.columns = 'TSLA GM FORD'.split()
allopen
# Out:
#               TSLA     GM   FORD
# Date
# 2012-01-03   28.94  20.83  11.00
# 2012-01-04   28.21  21.05  11.15
# 2012-01-05   27.76  21.10  11.33
# 2012-01-06   27.20  22.26  11.74
# 2012-01-09   27.00  23.20  11.83
# ...            ...    ...    ...
# 2016-12-23  208.00  35.83  12.43
# 2016-12-27  214.88  35.80  12.43
# 2016-12-28  221.53  35.74  12.37
# 2016-12-29  218.56  35.25  12.25
# 2016-12-30  216.30  35.21  12.24
#
# [1258 rows x 3 columns]

# %%
# Code Here
# fig, ax = plt.subplots(figsize=(15,10))
px.line(allopen)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fe8037fb-2ba2-47f6-a699-d6d4790a7f24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe8037fb-2ba2-47f6-a699-d6d4790a7f24")) {                    Plotly.newPlot(                        "fe8037fb-2ba2-47f6-a699-d6d4790a7f24",                        [{"hovertemplate":"variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"TSLA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TSLA","showlegend":true,"x":["2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-25T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-21T00:00:00","2012-02-22T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-30T00:00:00","2012-05-01T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-29T00:00:00","2012-05-30T00:00:00","2012-05-31T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-07T00:00:00","2012-06-08T00:00:00","2012-06-11T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-14T00:00:00","2012-06-15T00:00:00","2012-06-18T00:00:00","2012-06-19T00:00:00","2012-06-20T00:00:00","2012-06-21T00:00:00","2012-06-22T00:00:00","2012-06-25T00:00:00","2012-06-26T00:00:00","2012-06-27T00:00:00","2012-06-28T00:00:00","2012-06-29T00:00:00","2012-07-02T00:00:00","2012-07-03T00:00:00","2012-07-05T00:00:00","2012-07-06T00:00:00","2012-07-09T00:00:00","2012-07-10T00:00:00","2012-07-11T00:00:00","2012-07-12T00:00:00","2012-07-13T00:00:00","2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:0 ...

# %% [markdown]
# ____

# %% [markdown]
# ** Plot the Volume of stock traded each day.**

# %%
allvolume = pd.concat([tsla.Volume, gm.Volume, ford.Volume], axis=1)
allvolume.columns = 'TSLA GM FORD'.split()
allvolume
# Out:
#                TSLA        GM      FORD
# Date
# 2012-01-03   928052   9321420  45709811
# 2012-01-04   630036   7856752  79725188
# 2012-01-05  1005432  17884040  67877467
# 2012-01-06   687081  18234608  59840605
# 2012-01-09   896951  12091714  53981467
# ...             ...       ...       ...
# 2016-12-23  4670464   9351152  15621178
# 2016-12-27  5915732   6008707  19467440
# 2016-12-28  3782456   8451852  26875381
# 2016-12-29  4044968   4416668  19819081
# 2016-12-30  4642620   7646079  27405736
#
# [1258 rows x 3 columns]

# %%
px.line(allvolume)
# Out:
# <div>                            <div id="ef9b0c50-4799-4b84-ab3c-8f3ee9c2c720" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef9b0c50-4799-4b84-ab3c-8f3ee9c2c720")) {                    Plotly.newPlot(                        "ef9b0c50-4799-4b84-ab3c-8f3ee9c2c720",                        [{"hovertemplate":"variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"TSLA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TSLA","showlegend":true,"x":["2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-25T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-21T00:00:00","2012-02-22T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-30T00:00:00","2012-05-01T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-29T00:00:00","2012-05-30T00:00:00","2012-05-31T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-07T00:00:00","2012-06-08T00:00:00","2012-06-11T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-14T00:00:00","2012-06-15T00:00:00","2012-06-18T00:00:00","2012-06-19T00:00:00","2012-06-20T00:00:00","2012-06-21T00:00:00","2012-06-22T00:00:00","2012-06-25T00:00:00","2012-06-26T00:00:00","2012-06-27T00:00:00","2012-06-28T00:00:00","2012-06-29T00:00:00","2012-07-02T00:00:00","2012-07-03T00:00:00","2012-07-05T00:00:00","2012-07-06T00:00:00","2012-07-09T00:00:00","2012-07-10T00:00:00","2012-07-11T00:00:00","2012-07-12T00:00:00","2012-07-13T00:00:00","2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:0 ...

# %% [markdown]
# ** Interesting, looks like Ford had a really big spike somewhere in late 2013. What was the date of this maximum trading volume for Ford?**
#
# **Bonus: What happened that day? **

# %%
ford[ford.Volume == ford.Volume.max()].index[0]
# Out:
# Timestamp('2013-12-18 00:00:00')

# %% [markdown]
# Ford’s stock dives as company warns on overseas profit.

# %% [markdown]
# ____

# %% [markdown]
# ** The Open Price Time Series Visualization makes Tesla look like its always been much more valuable as a company than GM and Ford. But to really understand this we would need to look at the total market cap of the company, not just the stock price. Unfortunately our current data doesn't have that information of total units of stock present. But what we can do as a simple calcualtion to try to represent total money traded would be to multply the Volume column by the Open price. Remember that this still isn't the actual Market Cap, its just a visual representation of the total amount of money being traded around using the time series. (e.g. 100 units of stock at \$10 each versus 100000 units of stock at $1 each)**

# %% [markdown]
# ** Create a new column for each dataframe called "Total Traded" which is the Open Price multiplied by the Volume Traded.**

# %%
# Code Here 
tsla['Total Traded'] = tsla['Open']*tsla['Volume']
gm['Total Traded'] = gm['Open']*gm['Volume']
ford['Total Traded'] = ford['Open']*ford['Volume']

# %% [markdown]
# ** Plot this "Total Traded" against the time index.**

# %%
# Code here
alltotal_traded = pd.concat([tsla['Total Traded'],gm['Total Traded'], ford['Total Traded']], axis=1)
alltotal_traded.columns = 'TSLA GM FORD'.split()
px.line(alltotal_traded)

# px.line(ford['Total Traded'])
# Out:
# <div>                            <div id="d68ac9ac-7998-4ee4-a43d-cf8f09221376" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d68ac9ac-7998-4ee4-a43d-cf8f09221376")) {                    Plotly.newPlot(                        "d68ac9ac-7998-4ee4-a43d-cf8f09221376",                        [{"hovertemplate":"variable=TSLA<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"TSLA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TSLA","showlegend":true,"x":["2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-25T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-21T00:00:00","2012-02-22T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-30T00:00:00","2012-05-01T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-29T00:00:00","2012-05-30T00:00:00","2012-05-31T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-07T00:00:00","2012-06-08T00:00:00","2012-06-11T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-14T00:00:00","2012-06-15T00:00:00","2012-06-18T00:00:00","2012-06-19T00:00:00","2012-06-20T00:00:00","2012-06-21T00:00:00","2012-06-22T00:00:00","2012-06-25T00:00:00","2012-06-26T00:00:00","2012-06-27T00:00:00","2012-06-28T00:00:00","2012-06-29T00:00:00","2012-07-02T00:00:00","2012-07-03T00:00:00","2012-07-05T00:00:00","2012-07-06T00:00:00","2012-07-09T00:00:00","2012-07-10T00:00:00","2012-07-11T00:00:00","2012-07-12T00:00:00","2012-07-13T00:00:00","2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:0 ...

# %% [markdown]
# ** Interesting, looks like there was huge amount of money traded for Tesla somewhere in early 2014. What date was that and what happened? **

# %%
tsla[tsla['Total Traded'] == tsla['Total Traded'].max()].index[0]
# Out:
# Timestamp('2014-02-25 00:00:00')

# %% [markdown]
# ____

# %% [markdown]
# ** Let's practice plotting out some MA (Moving Averages). Plot out the MA50 and MA200 for GM. **

# %%
# Code here
gm['MA50'] = gm.Open.rolling(50).mean()
gm['MA200'] = gm.Open.rolling(200).mean()
gm.iloc[:,-2:].plot(figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
px.line(gm[['Open','MA50','MA200']])
# Out:
# <div>                            <div id="c0f2b9d0-6bb7-4811-8b93-ea3b7eb9a89a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0f2b9d0-6bb7-4811-8b93-ea3b7eb9a89a")) {                    Plotly.newPlot(                        "c0f2b9d0-6bb7-4811-8b93-ea3b7eb9a89a",                        [{"hovertemplate":"variable=Open<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Open","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Open","showlegend":true,"x":["2012-01-03T00:00:00","2012-01-04T00:00:00","2012-01-05T00:00:00","2012-01-06T00:00:00","2012-01-09T00:00:00","2012-01-10T00:00:00","2012-01-11T00:00:00","2012-01-12T00:00:00","2012-01-13T00:00:00","2012-01-17T00:00:00","2012-01-18T00:00:00","2012-01-19T00:00:00","2012-01-20T00:00:00","2012-01-23T00:00:00","2012-01-24T00:00:00","2012-01-25T00:00:00","2012-01-26T00:00:00","2012-01-27T00:00:00","2012-01-30T00:00:00","2012-01-31T00:00:00","2012-02-01T00:00:00","2012-02-02T00:00:00","2012-02-03T00:00:00","2012-02-06T00:00:00","2012-02-07T00:00:00","2012-02-08T00:00:00","2012-02-09T00:00:00","2012-02-10T00:00:00","2012-02-13T00:00:00","2012-02-14T00:00:00","2012-02-15T00:00:00","2012-02-16T00:00:00","2012-02-17T00:00:00","2012-02-21T00:00:00","2012-02-22T00:00:00","2012-02-23T00:00:00","2012-02-24T00:00:00","2012-02-27T00:00:00","2012-02-28T00:00:00","2012-02-29T00:00:00","2012-03-01T00:00:00","2012-03-02T00:00:00","2012-03-05T00:00:00","2012-03-06T00:00:00","2012-03-07T00:00:00","2012-03-08T00:00:00","2012-03-09T00:00:00","2012-03-12T00:00:00","2012-03-13T00:00:00","2012-03-14T00:00:00","2012-03-15T00:00:00","2012-03-16T00:00:00","2012-03-19T00:00:00","2012-03-20T00:00:00","2012-03-21T00:00:00","2012-03-22T00:00:00","2012-03-23T00:00:00","2012-03-26T00:00:00","2012-03-27T00:00:00","2012-03-28T00:00:00","2012-03-29T00:00:00","2012-03-30T00:00:00","2012-04-02T00:00:00","2012-04-03T00:00:00","2012-04-04T00:00:00","2012-04-05T00:00:00","2012-04-09T00:00:00","2012-04-10T00:00:00","2012-04-11T00:00:00","2012-04-12T00:00:00","2012-04-13T00:00:00","2012-04-16T00:00:00","2012-04-17T00:00:00","2012-04-18T00:00:00","2012-04-19T00:00:00","2012-04-20T00:00:00","2012-04-23T00:00:00","2012-04-24T00:00:00","2012-04-25T00:00:00","2012-04-26T00:00:00","2012-04-27T00:00:00","2012-04-30T00:00:00","2012-05-01T00:00:00","2012-05-02T00:00:00","2012-05-03T00:00:00","2012-05-04T00:00:00","2012-05-07T00:00:00","2012-05-08T00:00:00","2012-05-09T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-14T00:00:00","2012-05-15T00:00:00","2012-05-16T00:00:00","2012-05-17T00:00:00","2012-05-18T00:00:00","2012-05-21T00:00:00","2012-05-22T00:00:00","2012-05-23T00:00:00","2012-05-24T00:00:00","2012-05-25T00:00:00","2012-05-29T00:00:00","2012-05-30T00:00:00","2012-05-31T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-07T00:00:00","2012-06-08T00:00:00","2012-06-11T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-14T00:00:00","2012-06-15T00:00:00","2012-06-18T00:00:00","2012-06-19T00:00:00","2012-06-20T00:00:00","2012-06-21T00:00:00","2012-06-22T00:00:00","2012-06-25T00:00:00","2012-06-26T00:00:00","2012-06-27T00:00:00","2012-06-28T00:00:00","2012-06-29T00:00:00","2012-07-02T00:00:00","2012-07-03T00:00:00","2012-07-05T00:00:00","2012-07-06T00:00:00","2012-07-09T00:00:00","2012-07-10T00:00:00","2012-07-11T00:00:00","2012-07-12T00:00:00","2012-07-13T00:00:00","2012-07-16T00:00:00","2012-07-17T00:00:00","2012-07-18T00:00:00","2012-07-19T00:00:00","2012-07-20T00:00:00","2012-07-23T00:00:00","2012-07-24T00:00:00","2012-07-25T00:00:00","2012-07-26T00:00:00","2012-07-27T00:00:00","2012-07-30T00:00:00","2012-07-31T00:00:00","2012-08-01T00:00:00","2012-08-02T00:0 ...

# %% [markdown]
# ______

# %% [markdown]
# ** Finally lets see if there is a relationship between these stocks, after all, they are all related to the car industry. We can see this easily through a scatter matrix plot. Import scatter_matrix from pandas.plotting and use it to create a scatter matrix plot of all the stocks'opening price. You may need to rearrange the columns into a new single dataframe. Hints and info can be found here: https://pandas.pydata.org/pandas-docs/stable/visualization.html#scatter-matrix-plot **

# %%
# sns.pairplot(allopen, diag_kind='hist')
from pandas.plotting import scatter_matrix
scatter_matrix(allopen,figsize=(20,15), hist_kwds={'bins':50})
plt.show()

# %% [markdown]
# _____
# ### Bonus Visualization Task! (Note: This is hard!)
# **Let's now create a candlestick chart! Watch the video if you get stuck on trying to recreate this visualization, there are quite a few steps involved!Refer to the video to understand how to interpret and read this chart. Hints: https://matplotlib.org/examples/pylab_examples/finance_demo.html**
#
# ** Create a CandleStick chart for Ford in January 2012 (too many dates won't look good for a candlestick chart)**

# %%
ford.index
# Out:
# DatetimeIndex(['2012-01-03', '2012-01-04', '2012-01-05', '2012-01-06',
#                '2012-01-09', '2012-01-10', '2012-01-11', '2012-01-12',
#                '2012-01-13', '2012-01-17',
#                ...
#                '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21',
#                '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28',
#                '2016-12-29', '2016-12-30'],
#               dtype='datetime64[ns]', name='Date', length=1258, freq=None)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=ford.index,
                open=ford.Open,
                high=ford.High,
                low=ford.Low,
                close=ford.Close)])

fig.show()
# Out:
# <div>                            <div id="294645f3-2645-4c83-bcdc-29c9b1a7e85e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("294645f3-2645-4c83-bcdc-29c9b1a7e85e")) {                    Plotly.newPlot(                        "294645f3-2645-4c83-bcdc-29c9b1a7e85e",                        [{"close":[11.13,11.3,11.59,11.71,11.8,11.8,12.07,12.14,12.04,12.02,12.34,12.61,12.59,12.66,12.82,12.93,12.79,12.21,12.29,12.42,12.33,12.26,12.79,12.96,12.88,12.84,12.69,12.44,12.54,12.48,12.38,12.74,12.75,12.53,12.28,12.4,12.23,12.3,12.25,12.38,12.66,12.72,12.46,12.09,12.24,12.46,12.58,12.43,12.7,12.88,12.9,12.51,12.63,12.54,12.57,12.32,12.32,12.48,12.32,12.32,12.5,12.48,12.62,12.64,12.5,12.47,12.22,11.79,11.91,12.07,11.92,11.88,11.91,11.79,11.66,11.41,11.35,11.39,11.73,11.87,11.6,11.28,11.23,11.1,10.92,10.67,10.66,10.61,10.69,10.71,10.58,10.32,10.15,10.16,10.01,10.01,10.2,10.19,10.41,10.59,10.6,10.84,10.66,10.56,10.12,10.04,10.19,10.57,10.55,10.66,10.45,10.5,10.3,10.41,10.35,10.34,10.56,10.65,10.27,10.19,10.01,10.01,10.02,10.09,9.59,9.39,9.6,9.57,9.5,9.45,9.35,9.33,9.13,9.27,9.26,9.34,9.38,9.35,9.21,9.17,9.06,8.97,8.96,9.0,9.1,9.24,9.24,8.92,9.09,9.15,9.31,9.35,9.34,9.35,9.4,9.44,9.49,9.59,9.63,9.63,9.53,9.49,9.45,9.49,9.39,9.34,9.32,9.31,9.34,9.41,9.57,9.92,10.14,10.11,10.15,10.21,10.34,10.53,10.39,10.42,10.59,10.44,10.4,10.32,10.09,10.01,10.02,9.86,9.93,9.79,9.94,10.11,10.16,10.05,10.1,9.98,10.14,10.12,10.22,10.3,10.41,10.43,10.18,10.17,10.0,10.17,10.39,10.36,11.16,11.25,11.17,11.25,11.42,11.06,10.9,10.93,10.97,11.0,10.67,10.57,10.5,10.83,10.85,10.92,11.1,11.1,11.1,11.25,11.53,11.45,11.41,11.31,11.31,11.24,11.48,11.47,11.49,11.47,11.27,11.1,11.39,11.67,11.73,11.77,11.86,12.4,12.79,12.76,12.87,12.95,13.2,13.46,13.57,13.43,13.35,13.47,13.83,14.0,13.99,14.3,14.22,14.22,14.11,14.17,13.88,13.87,13.68,13.78,13.14,12.93,12.95,13.02,12.88,13.18,13.2,13.07,13.1,13.11,13.08,13.04,13.11,13.02,12.99,12.6,12.39,12.48,12.13,12.34,12.76,12.61,12.61,12.75,12.87,12.89,12.83,12.98,13.34,13.39,13.4,13.43,13.45,13.26,13.16,13.36,13.26,13.26,13.29,13.31,13.22,13.15,12.9,13.01,12.68,12.65,12.44,12.78,12.8,13.12,13.55,13.53,12.95,13.12,12.92,12.75,12.93,13.06,13.36,13.33,13.47,13.67,13.66,13.71,13.38,13.41,13.83,14.09,14.19,14.21,14.2,14.11,14.01,14.27,14.67,14.64,15.08,15.05,14.95,14.97,14.81,14.79,15.28,15.63,15.9,15.68,15.89,15.78,15.25,15.44,15.73,15.71,15.51,15.37,15.58,15.37,15.55,15.65,15.32,14.82,15.0,14.67,14.97,15.29,15.65,15.47,15.74,16.18,16.43,16.7,16.81,16.84,16.72,16.98,17.11,17.12,16.6,16.78,16.93,16.76,17.04,16.94,17.37,16.96,17.02,17.08,17.08,16.88,17.19,17.5,17.19,17.03,16.77,16.98,17.02,17.07,17.06,16.89,16.43,16.3,16.12,16.31,16.25,16.41,16.45,16.41,15.88,16.02,16.5,16.19,16.34,16.91,17.3,17.0,17.31,17.55,17.54,17.39,17.35,17.35,17.44,17.62,17.66,17.39,17.2,17.26,17.19,17.27,17.05,16.87,17.19,17.21,16.95,17.09,16.81,16.5,16.62,16.93,17.11,17.18,16.97,17.29,17.46,17.53,17.5,17.6,17.52,17.76,17.6,17.57,17.61,17.34,17.11,16.89,17.0,17.09,16.91,16.55,16.85,16.89,16.72,17.1,17.09,17.07,16.98,16.87,16.92,17.09,17.01,16.94,16.87,17.03,17.08,17.06,16.56,16.62,16.74,16.7,16.56,16.53,16.41,16.39,16.59,16.86,16.7,15.65,15.3,15.42,15.15,15.19,15.33,15.3,15.28,15.43,15.44,15.51,15.58,15.38,15.54,15.84,16.07,16.11,16.4,16.7,16.73,16.52,16.41,16.55,16.43,15.83,15.71,15.72,15.26,15.25,14.96,14.55,14.87,14.73,14.85,14.97,14.84,14.96,15.0,15.08,15.24,15.39,15.25,15.27,15.16,15.18,15.15,15.26,15.39,15.39,15.2,15.37,15.63,15.67,15.62,15.51,15.3,15.4,15.18,15.08,15.28,15.49,15.48,15.55,15.47,15.39,15.33,15.25,15.25,15.45,15.6,16.32,16.46,16.39,16.13,15.94,16.1,15.84,15.63,15.63,15.7,15.84,16.07,16.0,15.98,16.1,16.23,16.32,15.78,15.97,16.12,16.15,15.91,15.9,15.74,15.56,15.46,15.81,15.77,15.84,15.86,15.75,15.69,15.76,15.92,15.7 ...

# %% [markdown]
# ____
# # Part 3: Basic Financial Analysis
#
# Now it is time to focus on a few key financial calculations. This will serve as your transition to the second half of the course. All you need to do is follow along with the instructions, this will mainly be an exercise in converting a mathematical equation or concept into code using python and pandas, something we will do often when working with quantiative data! If you feel very lost in this section, don't worry! Just go to the solutions lecture and treat it as a code-along lecture, use whatever style of learning works best for you!
#
# Let's begin!
# ____

# %% [markdown]
# ## Daily Percentage Change
# First we will begin by calculating the daily percentage change. Daily percentage change is defined by the following formula:

# %% [markdown]
# $ r_t = \frac{p_t}{p_{t-1}} -1$

# %% [markdown]
# This defines r_t (return at time t) as equal to the price at time t divided by the price at time t-1 (the previous day) minus 1. Basically this just informs you of your percent gain (or loss) if you bought the stock on day and then sold it the next day. While this isn't necessarily helpful for attempting to predict future values of the stock, its very helpful in analyzing the volatility of the stock. If daily returns have a wide distribution, the stock is more volatile from one day to the next. Let's calculate the percent returns and then plot them with a histogram, and decide which stock is the most stable!

# %% [markdown]
# ** Create a new column for each dataframe called returns. This column will be calculated from the Close price column. There are two ways to do this, either a simple calculation using the .shift() method that follows the formula above, or you can also use pandas' built in pct_change method. **

# %%
tsla['Returns'] = tsla['Close'].pct_change()
gm['Returns'] = gm['Close'].pct_change()
ford['Returns'] = ford['Close'].pct_change()

# %%
tsla
# Out:
#               Open    High     Low   Close   Volume  Total Traded   Returns
# Date
# 2012-01-03   28.94   29.50   27.65   28.08   928052  2.685782e+07       NaN
# 2012-01-04   28.21   28.67   27.50   27.71   630036  1.777332e+07 -0.013177
# 2012-01-05   27.76   27.93   26.85   27.12  1005432  2.791079e+07 -0.021292
# 2012-01-06   27.20   27.79   26.41   26.89   687081  1.868860e+07 -0.008481
# 2012-01-09   27.00   27.49   26.12   27.25   896951  2.421768e+07  0.013388
# ...            ...     ...     ...     ...      ...           ...       ...
# 2016-12-23  208.00  213.45  207.71  213.34  4670464  9.714565e+08  0.023459
# 2016-12-27  214.88  222.25  214.42  219.53  5915732  1.271172e+09  0.029015
# 2016-12-28  221.53  223.80  217.20  219.74  3782456  8.379275e+08  0.000957
# 2016-12-29  218.56  219.20  214.12  214.68  4044968  8.840682e+08 -0.023027
# 2016-12-30  216.30  217.50  211.68  213.69  4642620  1.004199e+09 -0.004612
#
# [1258 rows x 7 columns]

# %%
ford
# Out:
#              Open   High    Low  Close    Volume  Total Traded   Returns
# Date
# 2012-01-03  11.00  11.25  10.99  11.13  45709811  5.028079e+08       NaN
# 2012-01-04  11.15  11.53  11.07  11.30  79725188  8.889358e+08  0.015274
# 2012-01-05  11.33  11.63  11.24  11.59  67877467  7.690517e+08  0.025664
# 2012-01-06  11.74  11.80  11.52  11.71  59840605  7.025287e+08  0.010354
# 2012-01-09  11.83  11.95  11.70  11.80  53981467  6.386008e+08  0.007686
# ...           ...    ...    ...    ...       ...           ...       ...
# 2016-12-23  12.43  12.46  12.36  12.46  15621178  1.941712e+08  0.004839
# 2016-12-27  12.43  12.51  12.36  12.39  19467440  2.419803e+08 -0.005618
# 2016-12-28  12.37  12.45  12.22  12.25  26875381  3.324485e+08 -0.011299
# 2016-12-29  12.25  12.31  12.22  12.23  19819081  2.427837e+08 -0.001633
# 2016-12-30  12.24  12.28  12.08  12.13  27405736  3.354462e+08 -0.008177
#
# [1258 rows x 7 columns]

# %%
gm
# Out:
#              Open   High    Low  Close    Volume  Total Traded     MA50  \
# Date
# 2012-01-03  20.83  21.18  20.75  21.05   9321420  1.941652e+08      NaN
# 2012-01-04  21.05  21.37  20.75  21.15   7856752  1.653846e+08      NaN
# 2012-01-05  21.10  22.29  20.96  22.17  17884040  3.773532e+08      NaN
# 2012-01-06  22.26  23.03  22.24  22.92  18234608  4.059024e+08      NaN
# 2012-01-09  23.20  23.43  22.70  22.84  12091714  2.805278e+08      NaN
# ...           ...    ...    ...    ...       ...           ...      ...
# 2016-12-23  35.83  35.87  35.54  35.69   9351152  3.350518e+08  33.6438
# 2016-12-27  35.80  35.93  35.50  35.54   6008707  2.151117e+08  33.7246
# 2016-12-28  35.74  35.80  35.13  35.15   8451852  3.020692e+08  33.8026
# 2016-12-29  35.25  35.48  35.12  35.14   4416668  1.556875e+08  33.8710
# 2016-12-30  35.21  35.31  34.67  34.84   7646079  2.692184e+08  33.9444
#
#                MA200   Returns
# Date
# 2012-01-03       NaN       NaN
# 2012-01-04       NaN  0.004751
# 2012-01-05       NaN  0.048227
# 2012-01-06       NaN  0.033829
# 2012-01-09       NaN -0.003490
# ...              ...       ...
# 2016-12-23  31.61535  0.000000
# 2016-12-27  31.63845 -0.004203
# 2016-12-28  31.66285 -0.010974
# 2016-12-29  31.68495 -0.000284
# 2016-12-30  31.70235 -0.008537
#
# [1258 rows x 9 columns]

# %% [markdown]
# ** Now plot a histogram of each companies returns. Either do them separately, or stack them on top of each other. Which stock is the most "volatile"? (as judged by the variance in the daily returns we will discuss volatility in a lot more detail in future lectures.)**

# %%
ford.Returns.plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tsla.Returns.plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gm.Returns.plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
all_return = pd.concat([tsla.Returns, gm.Returns, ford.Returns], axis=1)
all_return.columns = 'TSLA GM FORD'.split()
px.histogram(all_return)
# Out:
# <div>                            <div id="603e02b5-65d9-4a40-a1c2-64edac80e710" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("603e02b5-65d9-4a40-a1c2-64edac80e710")) {                    Plotly.newPlot(                        "603e02b5-65d9-4a40-a1c2-64edac80e710",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=TSLA<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TSLA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TSLA","offsetgroup":"TSLA","orientation":"v","showlegend":true,"x":[null,-0.013176638176638056,-0.021291952363767574,-0.008480825958702032,0.013387876534027399,0.013577981651376136,0.02208544532947143,0.000708466170740385,-0.1932743362831859,0.1671785870996052,0.007894736842105177,-0.0018649757553150792,-0.005979073243647215,0.006390977443609058,0.024280911468061328,0.02005835156819824,0.03468001430103684,0.013476157567380742,0.008182748039549992,-0.01690902942171124,0.01754385964912264,0.022650439486139318,0.02975206611570247,0.020866773675762618,-0.0062893081761006275,0.0104430379746836,0.020357031005324044,-0.04542664211172487,0.012540192926044913,0.053350269926961014,0.012963521254145238,0.0172619047619047,0.023112931538911585,-0.01344009150700598,-0.008115942028985579,0.00905902980713047,-0.022589052997393555,-0.003851851851851884,0.005651397977394446,-0.011830819284235572,0.02993115833582749,-0.01075268817204289,-0.007931844888366513,-0.019543973941368198,0.000302023557837483,-0.0015096618357487435,0.050498941638947636,0.03655728267127212,0.0022216051096919376,-0.022166805209199336,-0.00821762538962878,0.00914285714285712,-0.00962627406568528,-0.0005717552887363198,0.005434782608695565,-0.02133712660028453,-0.009302325581395321,0.09741784037558676,0.01443850267379676,-0.0023721665788085655,-0.013738441215323749,-0.002410929547280949,-0.01772287862513433,0.03909240021869875,-0.07918968692449346,-0.014857142857142902,-0.038573085846867694,-0.020814479638008976,0.019408502772643388,0.010577213659715756,0.0044856459330144816,-0.03989282524560889,-0.00031007751937983663,0.013027295285359619,0.015309246785058184,0.0,-0.03679131483715303,-0.0037570444583594487,0.03425518541797601,0.017623822546338763,-0.004478948939982019,-0.006298740251949653,0.01961968004829462,0.00473653049141487,-0.04360636417206831,-0.019408502772643277,0.020106817467797633,-0.07021866338158289,-0.004306061609804623,0.09647371922821035,-0.021541262135922334,-0.06790697674418611,-0.020958083832335328,-0.00849473326537542,-0.020904729266620903,-0.035351767588379435,0.04390420899854863,0.07021202641640589,0.00746995777849957,-0.022566086395873652,-0.016820580474934066,0.06306608520630674,-0.04039129062795843,-0.029924366984544593,-0.045762711864406835,-0.009591474245115417,0.0010760401721665591,0.04693658187029737,-0.009924709103353857,0.03975112340131348,-0.031914893617021156,0.018543956043955978,0.0037086985839513975,-0.012764528048370805,0.01769309288873755,0.06452691407556,0.007851758793969932,0.05266438142723584,-0.047069271758437004,0.049394221808015004,-0.01983422143280056,-0.04530353367562667,0.011072445428661926,-0.017209011264080143,-0.00382043935052534,-0.02844359220198145,0.008552631578947478,0.018590998043052753,-0.007684918347742653,0.016134236850597006,-0.006986344871387717,0.007675087943716186,0.03776578863852742,0.04740061162079501,0.04992700729927013,-0.07258064516129026,-0.0359820089955023,0.0037325038880249295,-0.014874496436318663,-0.03554576910978291,-0.026744944553163785,-0.029825737265415597,-0.02832469775474955,0.04905794525417706,-0.0731955269400203,0.00255941499085921,-0.04266958424507661,-0.005714285714285672,0.04482758620689653,0.036670333700036695,0.07003891050583655,-0.0383471074380165,0.011000343760742437,0.0180210 ...

# %% [markdown]
# ** Try also plotting a KDE instead of histograms for another view point. Which stock has the widest plot? **

# %%
all_return.plot.kde(figsize=(20,15))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ** Try also creating some box plots comparing the returns. **

# %%
px.box(all_return, title='Stock Return Box Plot')
# Out:
# <div>                            <div id="cd351757-db95-4c32-84fa-8a54d30a64b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd351757-db95-4c32-84fa-8a54d30a64b9")) {                    Plotly.newPlot(                        "cd351757-db95-4c32-84fa-8a54d30a64b9",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSLA","TSL ...

# %% [markdown]
# ## Comparing Daily Returns between Stocks
#
# ** Create a scatter matrix plot to see the correlation between each of the stocks daily returns. This helps answer the questions of how related the car companies are. Is Tesla begin treated more as a technology company rather than a car company by the market?**

# %%
scatter_matrix(all_return, figsize=(20,15), hist_kwds={'bins':50})
# Out:
# array([[<AxesSubplot:xlabel='TSLA', ylabel='TSLA'>,
#         <AxesSubplot:xlabel='GM', ylabel='TSLA'>,
#         <AxesSubplot:xlabel='FORD', ylabel='TSLA'>],
#        [<AxesSubplot:xlabel='TSLA', ylabel='GM'>,
#         <AxesSubplot:xlabel='GM', ylabel='GM'>,
#         <AxesSubplot:xlabel='FORD', ylabel='GM'>],
#        [<AxesSubplot:xlabel='TSLA', ylabel='FORD'>,
#         <AxesSubplot:xlabel='GM', ylabel='FORD'>,
#         <AxesSubplot:xlabel='FORD', ylabel='FORD'>]], dtype=object)

# %% [markdown]
# ** It looks like Ford and GM do have some sort of possible relationship, let's plot just these two against eachother in scatter plot to view this more closely!**

# %%
plt.figure(figsize=(20,15))
plt.scatter(gm.Returns, ford.Returns)

# %%
plt.figure(figsize=(20,15))
plt.hexbin(gm.Returns, ford.Returns, bins=10, cmap='coolwarm')

# %% [markdown]
# ____
# ## Cumulative Daily Returns
#
# Great! Now we can see which stock was the most wide ranging in daily returns (you should have realized it was Tesla, our original stock price plot should have also made that obvious).
#
# With daily cumulative returns, the question we are trying to answer is the following, if I invested $1 in the company at the beginning of the time series, how much would is be worth today? This is different than just the stock price at the current day, because it will take into account the daily returns. Keep in mind, our simple calculation here won't take into account stocks that give back a dividend. Let's look at some simple examples:

# %% [markdown]
# Lets us say there is a stock 'ABC' that is being actively traded on an exchange. ABC has the following prices corresponding to the dates given

# %% [markdown]
#     Date                        Price
#     01/01/2018                   10
#     01/02/2018                   15
#     01/03/2018                   20
#     01/04/2018                   25

# %% [markdown]
# **Daily Return** : Daily return is the profit/loss made by the stock compared to the previous day. (This is what ew just calculated above). A value above one indicates profit, similarly a value below one indicates loss. It is also expressed in percentage to convey the information better. (When expressed as percentage, if the value is above 0, the stock had give you profit else loss). So for the above example the daily returns would be

# %% [markdown]
#     Date                         Daily Return                  %Daily Return
#     01/01/2018                 10/10 =  1                          -
#     01/02/2018                 15/10 =  3/2                       50%
#     01/03/2018                 20/15 =  4/3                       33%
#     01/04/2018                 25/20 =  5/4                       20%

# %% [markdown]
# **Cumulative Return**: While daily returns are useful, it doesn't give the investor a immediate insight into the gains he had made till date, especially if the stock is very volatile. Cumulative return is computed relative to the day investment is made.  If cumulative return is above one, you are making profits else you are in loss. So for the above example cumulative gains are as follows

# %% [markdown]
#     Date                       Cumulative Return         %Cumulative Return
#     01/01/2018                  10/10 =  1                         100 %
#     01/02/2018                  15/10 =  3/2                       150 %
#     01/03/2018                  20/10 =  2                         200 %
#     01/04/2018                  25/10 =  5/2                       250 %

# %% [markdown]
# The formula for a cumulative daily return is:
#
# $ i_i = (1+r_t) * i_{t-1} $
#
# Here we can see we are just multiplying our previous investment at i at t-1 by 1+our percent returns. Pandas makes this very simple to calculate with its cumprod() method. Using something in the following manner:
#
#     df[daily_cumulative_return] = ( 1 + df[pct_daily_return] ).cumprod()

# %% [markdown]
# ** Create a cumulative daily return column for each car company's dataframe.**

# %% [markdown]
# ** Now plot the Cumulative Return columns against the time series index. Which stock showed the highest return for a $1 invested? Which showed the lowest?**

# %% [markdown]
# # Great Job!
#
# That is it for thsi very basic analysis, this concludes this half of the course, which focuses much more on learning the tools of the trade. The second half of the course is where we really dive into functionality designed for time series, quantitative analysis, algorithmic trading, and much more!
